# %% [markdown]
# # WiFi Localisation Starting Notebook
# ## Cyberthon 2022 organised by CSIT, DCO and HCI
#
# This notebook is to help people interact with the data, you may use it if you want to or not.
#
# ALT-TAB LABS LLP &copy; 2019 - 2022 All Rights Reserved

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# feel free to add any library you need

# %%
# load training data
df0 = pd.read_json("./wifi_train.json")
df0.describe()
# Out:
#        9vdEmSoDVo5bPvTqLEci qOlzm9dWsWbSTRqfc9x0 1mlZkF81youDiadsCub0  \
# count                     8                    8                    8
# unique                    8                    8                    8
# top           B2L2 ACCURATE        B2L2 ACCURATE        B2L2 ACCURATE
# freq                      1                    1                    1
#
#        capZWyIwXHbhuXh67dPx jo2EGFLxlr5pEtUr2hIw 2HJ59WoZEY8QYMDeVNJ9  \
# count                     8                    8                    8
# unique                    8                    8                    8
# top           B2L2 ACCURATE        B2L2 ACCURATE        B2L2 ACCURATE
# freq                      1                    1                    1
#
#        cS565f9XQWeyYG9etG9R dU0La1yLqRDPqAbxI0g9 6qxhQwhZsas7S9HkcGmv  \
# count                     8                    8                    8
# unique                    8                    8                    8
# top           B2L2 ACCURATE        B2L2 ACCURATE        B2L2 ACCURATE
# freq                      1                    1                    1
#
#        e4SYxYNJiyHRpdWb50uK  ... FMIDAN951McoonAtWDFE ztPqW3dRWXz60Bw8ubjg  \
# count                     8  ...                    8                    8
# unique                    8  ...                    8                    8
# top           B2L2 ACCURATE  ...        B2L2 ACCURATE        B2L2 ACCURATE
# freq                      1  ...                    1                    1
#
#        2HVZqpty0FRBGl66Fhqd McAmTquLrT1q1nbpWuzA 9KIssMatNQMu20uCPkZO  \
# count                     8                    8                    8
# unique                    8                    8                    8
# top           B2L2 ACCURATE        B2L2 ACCURATE        B2L2 ACCURATE
# freq                      1                    1                    1
#
#        DsxvYPLVDQQdbXCjlGCe WHJfDSbNggDnH1mRzSoX et9ILG7uZyJIdBZgLOk8  \
# count                     8                    8                    8
# unique                    8                    8                    8
# top           B2L2 ACCURATE        B2L2 ACCURATE        B2L2 ACCURATE
# freq                      1                    1                    1
#
#        pSwO7lLaIpNDVPvwEroZ DboAV4VBoOIrkMdMhmjL
# count                     8                    8
# unique                    8                    8
# top           B2L2 ACCURATE        B2L2 ACCURATE
# freq                      1                    1
#
# [4 rows x 404 columns]

# %%
# lets take a look at the results of one scan
scanid = '9vdEmSoDVo5bPvTqLEci'
print('scan name:', df0[scanid]['name'])
print('phone used to scan:', df0[scanid]['device'])
print('known location of phone:', df0[scanid]['location'])
print('time of scan (UNIX epoch):', df0[scanid]['timestamp']['value']['_seconds'])
# print('Dictionary of scan data:', df0[scanid]['data']) # uncomment to see the whole dictionary
# print('All BSSIDs in scan:', df0[scanid]['data'].keys()) # uncomment to see the whole list
print('RSSI values measured from a specific BSSID 18:64:72:56:2d:61:', df0[scanid]['data']['18:64:72:56:2d:61'])
# Out:
# scan name: B2L2 ACCURATE
# phone used to scan: SM-G985F
# known location of phone: {'x': 0.15880000591278, 'y': 0.58840000629425}
# time of scan (UNIX epoch): 1616491191
# RSSI values measured from a specific BSSID 18:64:72:56:2d:61: [-78, -71, -75, -75]

# %%
# preprocess your data

# sample iteration over df0
for scanid in df0:
    locationX = df0[scanid]['location']['x']
    locationY = df0[scanid]['location']['y']
    # print(ssid, locationX, locationY) # this prints 404 lines
    # do some other stuff you want to

# %%
# format training data
# do train_test_split

# %%
# define your model

# %%
# do your training here

# %%
# do your validation here

# %%
# use plt to visualise your model's performance (optional)
#
# fig, ax = plt.subplots(figsize=(10,10))
# ax.scatter(y_true_x, y_true_y) # change these variables to your ones
# ax.scatter(y_pred_x, y_pred_y) # change these variables to your ones

# %%
# load test data
df1 = pd.read_json("./wifi_test.json")
df1.describe()
# Out:
#                                      KnW7bcCTFKSkaxQM9HwS  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:55:fe:d6': [-84, -85, -84, -83, -86...
# freq                                                    1
#
#                                      WVdanpyXB4Le6D7Qlxqm  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:55:f2:b3': [-68, -63, -60, -66, -71...
# freq                                                    1
#
#                                      yr3L2JcYm938dXdtCYj0  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:56:10:36': [-86, -84, -83], '18:64:...
# freq                                                    1
#
#                                      9MGDml7ZSWLVrxkytoR8  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:55:2a:d1': [-85], '18:64:72:55:fc:9...
# freq                                                    1
#
#                                      bFesNkqRjhgvo7bAHQs6  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:56:40:51': [-86, -85], '18:64:72:55...
# freq                                                    1
#
#                                      9xtGXaudjqX40DDTw2wc  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:55:e5:b3': [-92, -93, -89], '18:64:...
# freq                                                    1
#
#                                      x73WexagJ3epot4Vt5hI  \
# count                                                   8
# unique                                                  8
# top     {'24:de:c6:fa:86:f4': [-92], '18:64:72:56:5b:3...
# freq                                                    1
#
#                                      HFne5SeGBk44BKDH4zS2  \
# count                                                   8
# unique                                                  8
# top     {'04:8c:9a:25:04:9e': [-93], '18:64:72:56:79:7...
# freq                                                    1
#
#                                      w8Pjg1FP9CweGmwiNdaM  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:56:10:23': [-85, -84], '18:64:72:56...
# freq                                                    1
#
#                                      zcjOWinxMd4Xw3aysC9x  ...  \
# count                                                   8  ...
# unique                                                  8  ...
# top     {'18:64:72:56:64:f2': [-90], '18:64:72:56:33:c...  ...
# freq                                                    1  ...
#
#                                      dpmzX8WRwIywLxWZLVAd  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:55:fe:d3': [-87, -88], '18:64:72:55...
# freq                                                    1
#
#                                      GQ3QR7GIeS1NZxQnYfHR  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:56:7a:33': [-93], '18:64:72:56:2e:1...
# freq                                                    1
#
#                                      zdI1UZe1hKbMzxAEAnoi  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:55:2b:c3': [-80, -81], '24:de:c6:e4...
# freq                                                    1
#
#                                      ggOpXDbzjI5hLVh2G6cn  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:56:64:f7': [-88], '18:64:72:55:3c:4...
# freq                                                    1
#
#                                      GU4HX4y0l1Pm8cGukyKA  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:56:4d:56': [-80, -79, -84, -84, -80...
# freq                                                    1
#
#                                      dHXIwA3dTzHRZjpxlA3Y  \
# count                                                   8
# unique                                                  8
# top     {'24:de:c6:f0:72:e5': [-77, -66, -85, -76], '1...
# freq                                                    1
#
#                                      n3y4V2w0XSK8O92AUsM6  \
# count                                                   8
# unique                                                  8
# top     {'d8:c7:c8:45:9c:31': [-87], '24:de:c6:e4:67:e...
# freq                                                    1
#
#                                      zekUyNFAwIx2rBmVjJAX  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:55:ea:17': [-90], '06:90:e8:4e:60:9...
# freq                                                    1
#
#                                      f1Vq2wQO5RObCX2pZetw  \
# count                                                   8
# unique                                                  8
# top     {'18:64:72:55:fc:92': [-84, -85], '18:64:72:55...
# freq                                                    1
#
#                                      BTWjsEIjfE4ZVZkHbXCo
# count                                                   8
# unique                                                  8
# top     {'24:de:c6:fa:86:f3': [-92], '18:64:72:56:4f:5...
# freq                                                    1
#
# [4 rows x 101 columns]

# %%
# preprocess your test data

# sample iteration over df0
for scanid in df1:
    locationX = df1[scanid]['location']['x']
    locationY = df1[scanid]['location']['y']
    # print(ssid, locationX, locationY) # this prints 404 lines
    # do some other stuff you want to

# %%
# format test data

# %%
# predict the location X and Y using your model

# %%
# generate mysubmission
df2 = pd.read_csv('submission.csv')
for i, row in df2.iterrows():
    df2.at[i,'locationX'] = 0
    df2.at[i,'locationY'] = 0

print(df2)
# Out:
#       id                scanid locationX locationY
# 0      0  KnW7bcCTFKSkaxQM9HwS         0         0
# 1      1  WVdanpyXB4Le6D7Qlxqm         0         0
# 2      2  yr3L2JcYm938dXdtCYj0         0         0
# 3      3  9MGDml7ZSWLVrxkytoR8         0         0
# 4      4  bFesNkqRjhgvo7bAHQs6         0         0
# ..   ...                   ...       ...       ...
# 96    96  dHXIwA3dTzHRZjpxlA3Y         0         0
# 97    97  n3y4V2w0XSK8O92AUsM6         0         0
# 98    98  zekUyNFAwIx2rBmVjJAX         0         0
# 99    99  f1Vq2wQO5RObCX2pZetw         0         0
# 100  100  BTWjsEIjfE4ZVZkHbXCo         0         0
#
# [101 rows x 4 columns]

# %%
# save mysubmission to file mysubmission.csv
df2.to_csv('./mysubmission.csv', index=False)

# %% [markdown]
# # Submitting to the CTFSG DataScience Grader
# ALT-TAB LABS LLP &copy; 2020-2021 All Rights Reserved

# %% [markdown]
# # Using the web interface
#
# Just visit the grader URL provided with the questions and upload using the web interface:
# http://ABC.XYZ.ctf.sg:12345/

# %% [markdown]
# # Using the python library

# %%
# Download CTFSG Grader Libraries
import urllib.request, os
urllib.request.urlretrieve('https://raw.githubusercontent.com/alttablabs/ctfsg-utils/master/pyctfsglib.py', './pyctfsglib.py')
print('Downloaded pyctfsglib.py:', 'pyctfsglib.py' in os.listdir())

# %%
# Connect to graders
import pyctfsglib as ctfsg
import random

USER_TOKEN = "USER_TOKEN" # You need to fill this up
GRADER_URL = random.choice([ # Check if these are correct GRADER URLS for the specific challenge
    "http://ABC.XYZ.ctf.sg:12345/",
    "http://ABC.XYZ.ctf.sg:23456/"
])

grader = ctfsg.DSGraderClient(GRADER_URL, USER_TOKEN)

# %%
# Submitting a file
grader.submitFile('./mysubmission.csv')
